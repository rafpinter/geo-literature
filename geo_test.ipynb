# %%
import plotly.express as px

df = px.data.gapminder().query("year==2007")
fig = px.choropleth(df, locations="iso_alpha",
                    color="lifeExp", # lifeExp is a column of gapminder
                    hover_name="country", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/rafaelapinter/Documents/Python/geo-literaria/geo_test.ipynb Célula: 1 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/rafaelapinter/Documents/Python/geo-literaria/geo_test.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df = px.data.gapminder().query("year==2007")
#       <a href='vscode-notebook-cell:/Users/rafaelapinter/Documents/Python/geo-literaria/geo_test.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> fig = px.choropleth(df, locations="iso_alpha",
#       <a href='vscode-notebook-cell:/Users/rafaelapinter/Documents/Python/geo-literaria/geo_test.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>                     color="lifeExp", # lifeExp is a column of gapminder
# ...

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
df[['iso_alpha', 'lifeExp']]
# Out:
#      iso_alpha  lifeExp
# 11         AFG   43.828
# 23         ALB   76.423
# 35         DZA   72.301
# 47         AGO   42.731
# 59         ARG   75.320
# 71         AUS   81.235
# 83         AUT   79.829
# 95         BHR   75.635
# 107        BGD   64.062
# 119        BEL   79.441
# 131        BEN   56.728
# 143        BOL   65.554
# 155        BIH   74.852
# 167        BWA   50.728
# 179        BRA   72.390
# 191        BGR   73.005
# 203        BFA   52.295
# 215        BDI   49.580
# 227        KHM   59.723
# 239        CMR   50.430
# 251        CAN   80.653
# 263        CAF   44.741
# 275        TCD   50.651
# 287        CHL   78.553
# 299        CHN   72.961
# 311        COL   72.889
# 323        COM   65.152
# 335        COD   46.462
# 347        COG   55.322
# 359        CRI   78.782
# 371        CIV   48.328
# 383        HRV   75.748
# 395        CUB   78.273
# 407        CZE   76.486
# 419        DNK   78.332
# 431        DJI   54.791
# 443        DOM   72.235
# ...

# %% [markdown]
# ---

# %%
import pandas as pd
from country_names import country_names

# %%
url = 'https://docs.google.com/spreadsheets/d/1yVzmSE9wdSpsH3EmrMHBY2fsu6oVJwqEAYtdE7rS-Qc/export?format=csv&id=1yVzmSE9wdSpsH3EmrMHBY2fsu6oVJwqEAYtdE7rS-Qc&gid=598270524'
df = pd.read_csv(url)
df.head()
# Out:
#   sigla_pais nome_pais              autor                       pub   ano  \
# 0        MAR  Marrocos  Badia Hadj Nasser         Le voile mis à nu  1984
# 1        MAR  Marrocos  Siham Benchekroun                Amoureuses  2013
# 2        MAR  Marrocos    Bouthaïna Azami  Au café des faits divers  2013
# 3        MAR  Marrocos     Bahaa Trabelsi        Parlez-moi d’amour  2013
# 4        CMR  Camarões      Léonora Miano         Rouge Impératrice  2019
#
#                                               resumo  \
# 0  Univers de femmes à fleur de corps, de nudité....
# 1  Ce recueil de textes intenses et audacieux, mê...
# 2  Accroché à Yvan, Sofia regarde le citronnier d...
# 3  Je l’ai rencontrée sur Facebook. Tous les deux...
# 4  Le lieu : Katiopa, un continent africain prosp...
#
#                                             link_ref
# 0  https://www.amazon.fr/Voile-mis-%C3%A0-nu-eboo...
# 1         http://www.sihambenchekroun.com/amoureuses
# ...

# %%
sheet_id = "1yVzmSE9wdSpsH3EmrMHBY2fsu6oVJwqEAYtdE7rS-Qc"
tab_id = "0"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&id={sheet_id}&gid={tab_id}"

lgbt_index_df = pd.read_csv(url)

# %%
lgbt_index_df
# Out:
#      INDEX                           COUNTRY  EQUALITY  LEGAL  PUBLIC_OPINION
# 0        1                           Iceland        90     94            86.0
# 1        2                            Canada        90    100            79.0
# 2        3                       Isle of Man        88     88             NaN
# 3        4                           Uruguay        87    100            75.0
# 4        5                            Norway        86     90            81.0
# 5        6                           Andorra        85     97            73.0
# 6        7                       Netherlands        85     96            73.0
# 7        8                           Germany        84     98            70.0
# 8        9                    United Kingdom        84     92            75.0
# 9       10                         Australia        84     94            73.0
# 10      11                       Switzerland        83     98            69.0
# ...

# %%
tab_id = "1833588588"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&id={sheet_id}&gid={tab_id}"

iso_codes = pd.read_csv(url)

# %%
iso_codes.loc[iso_codes['ISO-2'] == 'AF',"ISO-3"].item()
# Out:
# 'AFG'

# %%
iso_codes.head()
# Out:
#           Country ISO-2 ISO-3  Numeric
# 0     Afghanistan    AF   AFG        4
# 1         Albania    AL   ALB        8
# 2         Algeria    DZ   DZA       12
# 3  American Samoa    AS   ASM       16
# 4         Andorra    AD   AND       20

# %%
pd.set_option('display.max_rows', None)
pd.merge(lgbt_index_df, iso_codes, left_on='COUNTRY', right_on='Country', how='left').sort_values(by='COUNTRY')
# Out:
#      INDEX                           COUNTRY  EQUALITY  LEGAL  PUBLIC_OPINION  \
# 197    198                       Afghanistan         1      0             2.0
# 102    103                           Albania        44     78            11.0
# 177    178                           Algeria        16      6            26.0
# 5        6                           Andorra        85     97            73.0
# 54      55                            Angola        63     79            47.0
# 118    119               Antigua and Barbuda        40     63            17.0
# 12      13                         Argentina        82     97            67.0
# 136    137                           Armenia        34     63             5.0
# 9       10                         Australia        84     94            73.0
# 33      34                           Austria        73     90            57.0
# 150    151                        Azerbaijan        29     54             4.0
# ...
